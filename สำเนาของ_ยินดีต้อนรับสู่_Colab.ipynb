# %% [markdown]
# <a href="https://colab.research.google.com/github/qkwr/-quote-generator--tikka-/blob/main/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_%E0%B8%A2%E0%B8%B4%E0%B8%99%E0%B8%94%E0%B8%B5%E0%B8%95%E0%B9%89%E0%B8%AD%E0%B8%99%E0%B8%A3%E0%B8%B1%E0%B8%9A%E0%B8%AA%E0%B8%B9%E0%B9%88_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

X = iris.data
y = iris.target


print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(  X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.94      1.00      0.97        15
#            2       1.00      0.94      0.97        16
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[19  0  0]
#  [ 0 15  0]
#  [ 0  1 15]]

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[19  0  0]
#  [ 0 15  0]
#  [ 0  1 15]]

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm)

plt.figure(figsize=(10.7, 7)) # Changed 10.7 to (10.7, 7) to specify width and height
sn.heatmap(df_cm, annot=True)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
เตรียมข้อมูลก่อนการประมวลผล
พอเตรีนมแล้ว เลือกแบบจำลอง แล้วลองรันดู
แต่เงื่อนไข อยากได้ผลลัพธ์ที่ดีที่สุด กลุ่มไหนได้ผลลัพธ์ที่ดีที่สุด
ต้องทำถูกทุกกระบวนการ ถึงจะได้ผลลัพธ์ที่ดีทีสุด
มีกบุ่มไหนทำถุกต้อง ครบถ้วน


สิ่งที่จะต้องส่ง คือโค้ด พร้อมรายงานสั้นๆว่าเราทำอะไรบ้าง
อธิบายว่าอ่ะ อิมพอต แล้วโหลด้อมูลม่ แล้งแบ่ง ฟีเจอร์กับคลาส เล่าเป็นภาษาคน

ส่งไฟล์เป็น jupiternotebook  โค้ด
ก็จะนั่งจิ้มถามว่า โค้ดคืออะไร
